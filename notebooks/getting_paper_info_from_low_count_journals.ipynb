# %%
import pandas as pd

# %%
df_paper_info = pd.read_csv("../data/paper_info_from_sophia_20210626.csv")

# %%
df_paper_info.head()
# Out:
#                                        doi  \
# 0      https://doi.org/10.1098/rsos.140322
# 1   https://doi.org/10.1098/rsbl.2004.0269
# 2  https://doi.org/10.1644/08-MAMM-A-108.1
# 3         https://doi.org/10.1038/35099670
# 4       https://doi.org/10.1093/icb/icl030
#
#                                                  url  \
# 0  https://royalsocietypublishing.org/doi/10.1098...
# 1  https://royalsocietypublishing.org/doi/10.1098...
# 2  https://academic.oup.com/jmammal/article/90/2/...
# 3           https://www.nature.com/articles/35099670
# 4  https://academic.oup.com/icb/article/46/5/587/...
#
#                                                title  \
# 0  Impact behaviour of freeze-dried and fresh pom...
# 1  Distribution of unique red feather pigments in...
# 2  Home Ranges, Movement, and Den Use in Long-Bea...
# 3                  Energy saving in flight formation
# 4  Revisiting synchronous gamete release by fucoi...
#
# ...

# %%
df_paper_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   doi              822 non-null    object
#  1   url              1232 non-null   object
#  2   title            830 non-null    object
#  3   abstract         821 non-null    object
#  4   full_doc_link    446 non-null    object
#  5   is_open_access   864 non-null    object
#  6   label_level_1    1227 non-null   object
#  7   label_level_2    1225 non-null   object
#  8   label_level_3    1137 non-null   object
#  9   journal          1231 non-null   object
#  10  literature_site  1232 non-null   object
#  11  Unnamed: 0       1232 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 115.6+ KB

# %%
# get list of top literature sites

# %%
df_lit_site = df_paper_info['literature_site']

# %%
df_lit_site.head()
# Out:
# 0    royalsocietypublishing.org
# 1    royalsocietypublishing.org
# 2              academic.oup.com
# 3                www.nature.com
# 4              academic.oup.com
# Name: literature_site, dtype: object

# %%
df_paper_info.groupby('literature_site')

# %%
df_grouped_by_lit_site = df_paper_info.groupby('literature_site').count()

# %%
df_grouped_by_lit_site.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 125 entries, academic.oup.com to zslpublications.onlinelibrary.wiley.com
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   doi             125 non-null    int64
#  1   url             125 non-null    int64
#  2   title           125 non-null    int64
#  3   abstract        125 non-null    int64
#  4   full_doc_link   125 non-null    int64
#  5   is_open_access  125 non-null    int64
#  6   label_level_1   125 non-null    int64
#  7   label_level_2   125 non-null    int64
#  8   label_level_3   125 non-null    int64
#  9   journal         125 non-null    int64
#  10  Unnamed: 0      125 non-null    int64
# dtypes: int64(11)
# memory usage: 11.7+ KB

# %%
pd.set_option('display.max_rows', 10)

# %%
df_grouped_by_lit_site.head(100)
# Out:
#                                  doi  url  title  abstract  full_doc_link  \
# literature_site
# academic.oup.com                  39   39     39        35             31
# acsess.onlinelibrary.wiley.com     0    1      0         0              0
# aem.asm.org                        0    3      0         0              0
# agris.fao.org                      0    1      0         0              0
# agupubs.onlinelibrary.wiley.com    0    2      0         0              0
# ...                              ...  ...    ...       ...            ...
# www.jbc.org                        0    6      0         0              0
# www.jci.org                        0    1      0         0              0
# www.journals.uchicago.edu         21   21     21        21             21
# www.jstage.jst.go.jp               0    1      0         0              0
# www.jstor.org                      0   38      0         0              0
#
# ...

# %%
df_grouped_by_lit_site_sorted = df_grouped_by_lit_site.sort_values(['url',], ascending=[0])

# %%
df_group = df_grouped_by_lit_site_sorted[df_grouped_by_lit_site_sorted['url']<20]

# %%
df_group.head()
# Out:
#                        doi  url  title  abstract  full_doc_link  \
# literature_site
# pubs.acs.org             0   19      0         0              0
# iopscience.iop.org       1   15      1         1              0
# www.annualreviews.org    1   11      1         1              0
# www.cambridge.org        0   10      0         0              0
# bioone.org               0   10      0         0              0
#
#                        is_open_access  label_level_1  label_level_2  \
# literature_site
# pubs.acs.org                        0             19             19
# iopscience.iop.org                  0             15             15
# www.annualreviews.org               0             11             11
# www.cambridge.org                   0             10             10
# bioone.org                          0             10             10
#
#                        label_level_3  journal  Unnamed: 0
# literature_site
# pubs.acs.org                      18       19          19
# ...

# %%
df_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109 entries, pubs.acs.org to zslpublications.onlinelibrary.wiley.com
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   doi             109 non-null    int64
#  1   url             109 non-null    int64
#  2   title           109 non-null    int64
#  3   abstract        109 non-null    int64
#  4   full_doc_link   109 non-null    int64
#  5   is_open_access  109 non-null    int64
#  6   label_level_1   109 non-null    int64
#  7   label_level_2   109 non-null    int64
#  8   label_level_3   109 non-null    int64
#  9   journal         109 non-null    int64
#  10  Unnamed: 0      109 non-null    int64
# dtypes: int64(11)
# memory usage: 10.2+ KB

# %%
low_count_lit_sites = list(df_group.index)
