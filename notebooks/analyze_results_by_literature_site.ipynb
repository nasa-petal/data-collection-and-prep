# %%
import pandas as pd

# %%
df_paper_info = pd.read_csv("../data/using_ss_api_db.csv")

# %%
df_paper_info.head()
# Out:
#                                        doi  \
# 0      https://doi.org/10.1098/rsos.140322
# 1   https://doi.org/10.1098/rsbl.2004.0269
# 2  https://doi.org/10.1644/08-MAMM-A-108.1
# 3         https://doi.org/10.1038/35099670
# 4       https://doi.org/10.1242/jeb.036871
#
#                                                  url  \
# 0  https://royalsocietypublishing.org/doi/10.1098...
# 1  https://royalsocietypublishing.org/doi/10.1098...
# 2  https://academic.oup.com/jmammal/article/90/2/...
# 3           https://www.nature.com/articles/35099670
# 4       https://jeb.biologists.org/content/213/2/288
#
#                                                title  \
# 0  Impact behaviour of freeze-dried and fresh pom...
# 1  Distribution of unique red feather pigments in...
# 2  Home Ranges, Movement, and Den Use in Long-Bea...
# 3                  Energy saving in flight formation
# 4  Correlation between aquaporin and water permea...
#
#                                             abstract  \
# 0  Pomelos (Citrus maxima) are known for their th...
# 1  In many birds, red, orange and yellow feathers...
# 2  Abstract Long-beaked echidnas (Zaglossus), whi...
# 3  Many species of large bird fly together in for...
# 4  SUMMARY The ventral pelvic skin of the tree fr...
#
#                                        full_doc_link is_open_access  \
# 0  https://royalsocietypublishing.org/doi/10.1098...           True
# 1  https://royalsocietypublishing.org/doi/10.1098...           True
# 2  https://academic.oup.com//jmammal/article-pdf/...          False
# 3       https://www.nature.com/articles/35099670.pdf           True
# 4  https://journals.biologists.com/jeb/article-pd...           True
#
#                                        label_level_1  \
# 0                  ['Maintain structural integrity']
# 1  ['Sense send or process information', 'Change ...
# 2         ['Process resources', 'Protect from harm']
# 3          ['Move', 'Maintain ecological community']
# 4                              ['Process resources']
#
#                                        label_level_2  \
# 0  ['Manage structural forces', 'Prevent structur...
# 1                   ['Send signals', 'Modify color']
# 2  ['Distribute resources', 'Protect from non-liv...
# 3                               ['Passive movement']
# 4  ['Capture resources', 'Absorb and/or filter re...
#
#                                        label_level_3  \
# 0      ['Manage impact', 'Prevent fracture/rupture']
# 1  ['Send light signals in the visible spectrum',...
# 2        ['Distribute gases', 'Protect from solids']
# 3  ['Coordinate by self-organization', 'Passively...
# 4                   ['Absorb and/or filter liquids']
#
#                                              journal  \
# 0  ['Advanced Engineering Materials', 'Royal Soci...
# 1                                ['Biology Letters']
# 2  ['Journal of Experimental Biology (JEB)', 'Jou...
# 3                                         ['Nature']
# 4  ['Journal of Experimental Biology (JEB)', 'End...
#
#               literature_site  Unnamed: 0
# 0  royalsocietypublishing.org         0.0
# 1  royalsocietypublishing.org         1.0
# 2            academic.oup.com         3.0
# 3              www.nature.com         4.0
# 4          jeb.biologists.org         6.0

# %%
df_paper_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1527 entries, 0 to 1526
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   doi              972 non-null    object
#  1   url              1527 non-null   object
#  2   title            956 non-null    object
#  3   abstract         955 non-null    object
#  4   full_doc_link    535 non-null    object
#  5   is_open_access   949 non-null    object
#  6   label_level_1    1185 non-null   object
#  7   label_level_2    1183 non-null   object
#  8   label_level_3    1099 non-null   object
#  9   journal          1358 non-null   object
#  10  literature_site  1526 non-null   object
#  11  Unnamed: 0       1527 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 143.3+ KB

# %%
# get list of top literature sites

# %%
df_lit_site = df_paper_info['literature_site']

# %%
df_lit_site.head()
# Out:
# 0    royalsocietypublishing.org
# 1    royalsocietypublishing.org
# 2              academic.oup.com
# 3                www.nature.com
# 4            jeb.biologists.org
# Name: literature_site, dtype: object

# %%
df_paper_info.groupby('literature_site').count()
# Out:
#                                          doi  url  title  abstract  \
# literature_site
# academic.oup.com                          48   48     48        44
# acsess.onlinelibrary.wiley.com             0    1      0         0
# advances.sciencemag.org                    3    4      0         1
# aem.asm.org                                0    3      0         0
# agris.fao.org                              0    1      0         0
# ...                                      ...  ...    ...       ...
# www.thefreelibrary.com                     0    1      0         0
# www.uregina.ca                             0    1      0         0
# www.yumpu.com                              0    1      0         0
# zookeys.pensoft.net                        0    1      0         0
# zslpublications.onlinelibrary.wiley.com    1    1      0         1
#
#                                          full_doc_link  is_open_access  \
# literature_site
# academic.oup.com                                    40              48
# acsess.onlinelibrary.wiley.com                       0               0
# advances.sciencemag.org                              0               0
# aem.asm.org                                          0               0
# agris.fao.org                                        0               0
# ...                                                ...             ...
# www.thefreelibrary.com                               0               0
# www.uregina.ca                                       0               0
# www.yumpu.com                                        0               0
# zookeys.pensoft.net                                  0               0
# zslpublications.onlinelibrary.wiley.com              0               0
#
#                                          label_level_1  label_level_2  \
# literature_site
# academic.oup.com                                    38             38
# acsess.onlinelibrary.wiley.com                       0              0
# advances.sciencemag.org                              0              0
# aem.asm.org                                          2              2
# agris.fao.org                                        1              1
# ...                                                ...            ...
# www.thefreelibrary.com                               1              1
# www.uregina.ca                                       0              0
# www.yumpu.com                                        1              1
# zookeys.pensoft.net                                  0              0
# zslpublications.onlinelibrary.wiley.com              0              0
#
#                                          label_level_3  journal  Unnamed: 0
# literature_site
# academic.oup.com                                    33       45          48
# acsess.onlinelibrary.wiley.com                       0        1           1
# advances.sciencemag.org                              0        1           4
# aem.asm.org                                          2        3           3
# agris.fao.org                                        1        1           1
# ...                                                ...      ...         ...
# www.thefreelibrary.com                               1        1           1
# www.uregina.ca                                       0        1           1
# www.yumpu.com                                        1        1           1
# zookeys.pensoft.net                                  0        0           1
# zslpublications.onlinelibrary.wiley.com              0        1           1
#
# [141 rows x 11 columns]

# %%
df_grouped_by_lit_site = df_paper_info.groupby('literature_site').count()

# %%
df_grouped_by_lit_site.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 141 entries, academic.oup.com to zslpublications.onlinelibrary.wiley.com
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   doi             141 non-null    int64
#  1   url             141 non-null    int64
#  2   title           141 non-null    int64
#  3   abstract        141 non-null    int64
#  4   full_doc_link   141 non-null    int64
#  5   is_open_access  141 non-null    int64
#  6   label_level_1   141 non-null    int64
#  7   label_level_2   141 non-null    int64
#  8   label_level_3   141 non-null    int64
#  9   journal         141 non-null    int64
#  10  Unnamed: 0      141 non-null    int64
# dtypes: int64(11)
# memory usage: 13.2+ KB

# %%
df_grouped_by_lit_site_sorted = df_grouped_by_lit_site.sort_values(['url',], ascending=[0])

# %%
df_group = df_grouped_by_lit_site_sorted[df_grouped_by_lit_site_sorted['url']<20]

# %%
df_group.head()
# Out:
#                                      doi  url  title  abstract  full_doc_link  \
# literature_site
# iopscience.iop.org                     2   18      1         2              0
# pubs.rsc.org                           3   13      1         1              0
# www.annualreviews.org                  1   12      1         1              0
# esajournals.onlinelibrary.wiley.com    0   12      0         0              0
# www.cambridge.org                      1   11      1         1              0
#
#                                      is_open_access  label_level_1  \
# literature_site
# iopscience.iop.org                                0             15
# pubs.rsc.org                                      0              9
# www.annualreviews.org                             0              9
# esajournals.onlinelibrary.wiley.com               0             10
# www.cambridge.org                                 0             10
#
#                                      label_level_2  label_level_3  journal  \
# literature_site
# iopscience.iop.org                              15             15       16
# pubs.rsc.org                                     9              9       12
# www.annualreviews.org                            9              9       12
# esajournals.onlinelibrary.wiley.com             10             10       12
# www.cambridge.org                               10              9       11
#
#                                      Unnamed: 0
# literature_site
# iopscience.iop.org                           18
# pubs.rsc.org                                 13
# www.annualreviews.org                        12
# esajournals.onlinelibrary.wiley.com          12
# www.cambridge.org                            11

# %%
df_group.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 123 entries, iopscience.iop.org to zslpublications.onlinelibrary.wiley.com
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   doi             123 non-null    int64
#  1   url             123 non-null    int64
#  2   title           123 non-null    int64
#  3   abstract        123 non-null    int64
#  4   full_doc_link   123 non-null    int64
#  5   is_open_access  123 non-null    int64
#  6   label_level_1   123 non-null    int64
#  7   label_level_2   123 non-null    int64
#  8   label_level_3   123 non-null    int64
#  9   journal         123 non-null    int64
#  10  Unnamed: 0      123 non-null    int64
# dtypes: int64(11)
# memory usage: 11.5+ KB

# %%
list(df_group.index)
# Out:
# ['iopscience.iop.org',
#  'pubs.rsc.org',
#  'www.annualreviews.org',
#  'esajournals.onlinelibrary.wiley.com',
#  'www.cambridge.org',
#  'bsapubs.onlinelibrary.wiley.com',
#  'journals.aps.org',
#  'bioone.org',
#  'www.nrcresearchpress.com',
#  'besjournals.onlinelibrary.wiley.com',
#  'nph.onlinelibrary.wiley.com',
#  'doi.org',
#  'aip.scitation.org',
#  'www.researchgate.net',
#  'aslopubs.onlinelibrary.wiley.com',
#  'www.jbc.org',
#  'www.plantphysiol.org',
#  'www.int-res.com',
#  'www.frontiersin.org',
#  'journals.physiology.org',
#  'advances.sciencemag.org',
#  'journals.sagepub.com',
#  'sfamjournals.onlinelibrary.wiley.com',
#  'books.google.com',
#  'www.osapublishing.org',
#  'chemistry-europe.onlinelibrary.wiley.com',
#  'elifesciences.org',
#  'citeseerx.ist.psu.edu',
#  'aem.asm.org',
#  'www.mdpi.com',
#  'www.microbiologyresearch.org',
#  'www.ingentaconnect.com',
#  'pdfs.semanticscholar.org',
#  'www.plantcell.org',
#  'www.spandidos-publications.com',
#  'www.publish.csiro.au',
#  'connection.ebscohost.com',
#  'www.semanticscholar.org',
#  'asa.scitation.org',
#  'agupubs.onlinelibrary.wiley.com',
#  'brill.com',
#  'europepmc.org',
#  'ieeexplore.ieee.org',
#  'iwaponline.com',
#  'jb.asm.org',
#  'www.academicjournals.org',
#  'zookeys.pensoft.net',
#  'www.crossref.org',
#  'www.apidologie.org',
#  'www.uregina.ca',
#  'www.beilstein-journals.org',
#  'www.2008.botanyconference.org',
#  'www.thefreelibrary.com',
#  'www.conservationgateway.org',
#  'www.theatlantic.com',
#  'www.yumpu.com',
#  'www.omicsonline.org',
#  'www.springer.com',
#  'www.cs.unm.edu',
#  'www.eurekaselect.com',
#  'www.osti.gov',
#  'www.scribd.com',
#  'www.scientificamerican.com',
#  'www.scientific.net',
#  'www.sciencedaily.com',
#  'www.jci.org',
#  'www.scielo.br',
#  'www.jstage.jst.go.jp',
#  'www.karger.com',
#  'umdberg.pbworks.com',
#  'web.a.ebscohost.com',
#  'physicstoday.scitation.org',
#  'ui.adsabs.harvard.edu',
#  'drive.google.com',
#  'jhr.pensoft.net',
#  'jcs.biologists.org',
#  'jcm.asm.org',
#  'frontiersinzoology.biomedcentral.com',
#  'etheses.whiterose.ac.uk',
#  'epubs.siam.org',
#  'epub.uni-regensburg.de',
#  'environmentalevidencejournal.biomedcentral.com',
#  'ec.asm.org',
#  'drs.nio.org',
#  'deepblue.lib.umich.edu',
#  'jnanobiotechnology.biomedcentral.com',
#  'csme.utah.edu',
#  'core.ac.uk',
#  'cdnsciencepub.com',
#  'bmcevolbiol.biomedcentral.com',
#  'bmcbiol.biomedcentral.com',
#  'bjo.bmj.com',
#  'avs.scitation.org',
#  'archive.org',
#  'airtable.com',
#  'agris.fao.org',
#  'jlimnol.it',
#  'jov.arvojournals.org',
#  'thescipub.com',
#  'physoc.onlinelibrary.wiley.com',
#  'stke.sciencemag.org',
#  'spo.nmfs.noaa.gov',
#  'rupress.org',
#  'rsta.royalsocietypublishing.org',
#  'ro.uow.edu.au',
#  'repository.si.edu',
#  'rd.springer.com',
#  'qz.com',
#  'pubs.geoscienceworld.org',
#  'portlandpress.com',
#  'acsess.onlinelibrary.wiley.com',
#  'kuscholarworks.ku.edu',
#  'physics.aps.org',
#  'phys.org',
#  'orbit.dtu.dk',
#  'msystems.asm.org',
#  'mmbr.asm.org',
#  'meridian.allenpress.com',
#  'members.optusnet.com.au',
#  'meetings.aps.org',
#  'mbio.asm.org',
#  'linkinghub.elsevier.com',
#  'zslpublications.onlinelibrary.wiley.com']
